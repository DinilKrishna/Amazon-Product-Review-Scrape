# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
base_url = 'https://www.amazon.in/LOreal-Paris-Excellence-Natural-Darkest/product-reviews/B006QHB88O/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber='

# %%
j = 1
review_data = []
for i in range(1, 11):
    url = f'{base_url}{i}'
    html_text = requests.get(url).text
    soup = BeautifulSoup(html_text, 'lxml')
    reviews = soup.find_all('div', class_ = 'a-section celwidget')
    for review in reviews:
        name = review.find('span', class_ = 'a-profile-name').text
        stars = review.find('span', class_ = 'a-icon-alt').text
        review = review.find('span', class_ = 'a-size-base review-text review-text-content').span.text
        print(j,":")
        print(f'Name: {name}')
        print(f'Stars: {stars}')
        print(f'Review: {review}')
        print()
        j += 1
        review_data.append({'Name': name, 'Stars': stars, 'Review': review})
# Out:
# 1 :
# Name: Poonam k.
# Stars: 5.0 out of 5 stars
# Review: Easy to use , good quality, premium feeling . Overall a very good product
#
# 2 :
# Name: 1 big bowl sent
# Stars: 4.0 out of 5 stars
# Review: Light shiny brownish color. Satisfied with my purchase.
#
# 3 :
# Name: Garvika kaushik
# Stars: 5.0 out of 5 stars
# Review: Delivery on time, Reasonable price... Good product 👍 ⭐⭐⭐⭐⭐
#
# 4 :
# Name: Dimpal
# Stars: 5.0 out of 5 stars
# Review: Dislike: priceLike : colour
#
# 5 :
# Name: Sudeshna Mohapatra
# Stars: 3.0 out of 5 stars
# Review: Despite using color protective shampoos , it hardly lasted for ten days.
#
# 6 :
# Name: Ritu Singh
# Stars: 5.0 out of 5 stars
# Review: Best hair color. Makes your hair very shiny and smooth and the conditioner we get with it is just awesome.
#
# 7 :
# Name: Rahul kumar
# Stars: 4.0 out of 5 stars
# Review: The color is staying for a long time and also not printing ur head skin black like a local color, lol
#
# 8 :
# Name: Manish Rao
# ...

# %%
df = pd.DataFrame(review_data)
df
# Out:
#                  Name               Stars  \
# 0           Poonam k.  5.0 out of 5 stars
# 1     1 big bowl sent  4.0 out of 5 stars
# 2     Garvika kaushik  5.0 out of 5 stars
# 3              Dimpal  5.0 out of 5 stars
# 4  Sudeshna Mohapatra  3.0 out of 5 stars
# 5          Ritu Singh  5.0 out of 5 stars
# 6         Rahul kumar  4.0 out of 5 stars
# 7          Manish Rao  5.0 out of 5 stars
# 8         Placeholder  4.0 out of 5 stars
# 9                Anup  4.0 out of 5 stars
#
#                                               Review
# 0  Easy to use , good quality, premium feeling . ...
# 1  Light shiny brownish color. Satisfied with my ...
# 2  Delivery on time, Reasonable price... Good pro...
# 3                        Dislike: priceLike : colour
# 4  Despite using color protective shampoos , it h...
# 5  Best hair color. Makes your hair very shiny an...
# 6  The color is staying for a long time and also ...
# 7                                         Best price
# ...

# %%
df.to_csv('Loreal_Paris_reviews.csv', index=False)

# %%
df1 = pd.read_csv('Loreal_Paris_reviews.csv')
